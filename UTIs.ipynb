# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('uti_tipo1.csv', sep=',',encoding='utf8' )
df
# Out:
#                 state  QT_EXIST  QT_EXIST.1
# 0             Alagoas       6.0           2
# 1             Alagoas       7.0           2
# 2             Alagoas       9.0           1
# 3             Alagoas      10.0           1
# 4               Amapá       6.0           2
# 5               Amapá       4.0           1
# 6               Amapá       5.0           1
# 7            Amazonas       1.0           1
# 8            Amazonas       2.0           1
# 9            Amazonas       4.0           1
# 10           Amazonas       6.0           1
# 11           Amazonas       7.0           1
# 12           Amazonas       8.0           1
# 13           Amazonas      10.0           1
# 14           Amazonas      16.0           1
# 15           Amazonas      20.0           1
# 16              Bahia       9.0           1
# 17              Bahia      11.0           1
# 18              Ceará       4.0           3
# 19              Ceará       2.0           2
# ...

# %%
df['QT_EXIST'].sum()
# Out:
# 3086.0

# %%
df1 = pd.read_csv('uti2_qtd_city.csv',sep=',',encoding='utf8')
df1
# Out:
#                   state  QT_EXIST
# 0                  Acre         4
# 1               Alagoas        12
# 2                 Amapá         1
# 3              Amazonas        14
# 4                 Bahia        52
# 5                 Ceará        32
# 6      Distrito Federal        17
# 7        Espírito Santo        29
# 8                 Goiás        21
# 9              Maranhão         9
# 10          Mato Grosso        23
# 11   Mato Grosso do Sul        10
# 12         Minas Gerais       117
# 13               Paraná        63
# 14              Paraíba        10
# 15                 Pará        15
# 16           Pernambuco        17
# 17                Piauí         9
# 18  Rio Grande do Norte        20
# 19    Rio Grande do Sul        63
# 20       Rio de Janeiro        87
# 21             Rondônia        10
# 22              Roraima         1
# 23       Santa Catarina        36
# 24              Sergipe         4
# 25            São Paulo       193
# ...

# %%
df1['QT_EXIST'].sum()
# Out:
# 870

# %%
df1.to_csv('uti2.csv',sep=',',encoding='utf8',header=True)

# %%
df2 = pd.read_csv('uti3_qtd_city.csv', sep=',',encoding='utf8')
df2
# Out:
#                   state  QT_EXIST
# 0               Alagoas      45.0
# 1                 Amapá      21.0
# 2              Amazonas      74.0
# 3                 Bahia      20.0
# 4                 Ceará      93.0
# 5      Distrito Federal     186.0
# 6        Espírito Santo      55.0
# 7                 Goiás      16.0
# 8              Maranhão      46.0
# 9           Mato Grosso      65.0
# 10   Mato Grosso do Sul      33.0
# 11         Minas Gerais     219.0
# 12               Paraná     218.0
# 13              Paraíba      20.0
# 14                 Pará      47.0
# 15           Pernambuco     157.0
# 16                Piauí      10.0
# 17  Rio Grande do Norte      74.0
# 18    Rio Grande do Sul      71.0
# 19       Rio de Janeiro    1421.0
# 20             Rondônia      19.0
# 21              Roraima       5.0
# 22       Santa Catarina      77.0
# 23              Sergipe      23.0
# 24            São Paulo    1886.0
# 25            Tocantins      18.0

# %%
df2['QT_EXIST'].sum()
# Out:
# 4919.0

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 2 columns):
# state       26 non-null object
# QT_EXIST    26 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 496.0+ bytes

# %%
df2['QT_EXIST'] = df2['QT_EXIST'].values.astype(np.int64)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 2 columns):
# state       26 non-null object
# QT_EXIST    26 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 496.0+ bytes

# %%
df2.to_csv('uti3.csv',sep=',',encoding='utf8',header=True)

# %%
utis = pd.read_csv('uti_total.csv',sep=',', encoding='utf8')
utis
# Out:
#                   state  soma_uti              state.1  soma_utis1  \
# 0               Alagoas       4.0                 Acre           4
# 1                 Amapá       3.0              Alagoas          12
# 2              Amazonas       9.0                Amapá           1
# 3                 Bahia       2.0             Amazonas          14
# 4                 Ceará       9.0                Bahia          52
# 5      Distrito Federal       7.0                Ceará          32
# 6        Espírito Santo       6.0     Distrito Federal          17
# 7                 Goiás       2.0       Espírito Santo          29
# 8              Maranhão       2.0                Goiás          21
# 9           Mato Grosso       2.0             Maranhão           9
# 10   Mato Grosso do Sul       4.0          Mato Grosso          23
# 11         Minas Gerais      12.0   Mato Grosso do Sul          10
# 12                 Pará       6.0         Minas Gerais         117
# ...

# %%
utis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 6 columns):
# state         26 non-null object
# soma_uti      26 non-null float64
# state.1       27 non-null object
# soma_utis1    27 non-null int64
# state.2       26 non-null object
# soma_utis     26 non-null float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 1.3+ KB

# %%
utis['soma_uti'] = utis['soma_uti'].values.astype(np.int64)

# %%
utis['soma_utis'] = utis['soma_utis'].values.astype(np.int64)

# %%
utis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 6 columns):
# state         26 non-null object
# soma_uti      27 non-null int64
# state.1       27 non-null object
# soma_utis1    27 non-null int64
# state.2       26 non-null object
# soma_utis     27 non-null int64
# dtypes: int64(3), object(3)
# memory usage: 1.3+ KB

# %%
3086 + 870 + 4919
# Out:
# 8875
